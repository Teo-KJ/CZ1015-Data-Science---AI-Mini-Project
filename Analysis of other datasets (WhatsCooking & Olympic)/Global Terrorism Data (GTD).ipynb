# %% [markdown]
# # Global Terrorism Dataset
# Over here we do analysis of the terrorism events that happened worldwide in the past since 1970 and determine the potential effects and relationship with the Olympics and entertainment events. However, unfortunately we are not able to use this dataset as the points are not strong to support a relationship with the Olympics.

# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
GTD = pd.read_csv('GTD.csv', index_col = 0)
GTD.head()
# Out:
#    Year  Month  Day        Country         Region         city   latitude  \
# 0  1970      1    1  United States  North America        Cairo  37.005105
# 1  1970      1    2  United States  North America      Madison  43.076592
# 2  1970      1    3  United States  North America      Madison  43.072950
# 3  1970      1    6  United States  North America       Denver  39.758968
# 4  1970      1    9  United States  North America  Rio Piedras  18.386932
#
#     longitude                      AttackType  Killed  Wounded  \
# 0  -89.176269                   Armed Assault     0.0      0.0
# 1  -89.412488  Facility/Infrastructure Attack     0.0      0.0
# 2  -89.386694  Facility/Infrastructure Attack     0.0      0.0
# 3 -104.876305  Facility/Infrastructure Attack     0.0      0.0
# 4  -66.061127  Facility/Infrastructure Attack     0.0      0.0
#
#                                               Target  \
# 0                          Cairo Police Headquarters
# ...

# %%
print("Data type : ", type(GTD))
print("Data dims : ", GTD.shape)
print(GTD.info())
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (43906, 17)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43906 entries, 0 to 43905
# Data columns (total 17 columns):
# Year           43906 non-null int64
# Month          43906 non-null int64
# Day            43906 non-null int64
# Country        43906 non-null object
# Region         43906 non-null object
# city           43906 non-null object
# latitude       43906 non-null float64
# longitude      43906 non-null float64
# AttackType     43906 non-null object
# Killed         43906 non-null float64
# Wounded        43906 non-null float64
# Target         43906 non-null object
# Summary        43906 non-null object
# Group          43906 non-null object
# Target_type    43906 non-null object
# Weapon_type    43906 non-null object
# Motive         43906 non-null object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 6.0+ MB
# None

# %%
GroupBy_Count= GTD.groupby('Country')['Year'].count()
GroupBy_Count
# Out:
# Country
# Afghanistan                 2900
# Albania                       12
# Algeria                     1249
# Angola                        67
# Argentina                     19
# Armenia                       10
# Australia                     27
# Austria                       16
# Azerbaijan                    11
# Bahrain                       48
# Bangladesh                   653
# Belarus                        8
# Belgium                       27
# Belize                         1
# Bhutan                         4
# Bolivia                        9
# Bosnia-Herzegovina            36
# Brazil                        17
# Bulgaria                      13
# Burkina Faso                   9
# Burundi                      145
# Cambodia                      29
# Cameroon                      23
# Canada                        46
# Central African Republic      48
# Chad                          20
# Chile                         72
# China                         88
# ...

# %%
array = ['United States', 'France', 'Germany',  'Greece', 'Japan', 'United Kingdom', 'Italy', 'Canada', 'Australia', 'Switzerland', 'Norway', 'Austria', 'Russia', 'South Korea', 'China','Brazil','Sweden','Belgium','Holland','Finland','Mexico','Spain','Yugoslavia', 'Singapore', 'Argentina']
OlympicsHost = GTD.loc[(GTD['Country'].isin(array))]
OlympicsHost
# Out:
#        Year  Month  Day         Country                 Region  \
# 0      1970      1    1   United States          North America
# 1      1970      1    2   United States          North America
# 2      1970      1    3   United States          North America
# 3      1970      1    6   United States          North America
# 4      1970      1    9   United States          North America
# 5      1970      1   12   United States          North America
# 6      1970      1   13   United States          North America
# 7      1970      1   19   United States          North America
# 8      1970      1   19   United States          North America
# 9      1970      1   19   United States          North America
# 10     1970      1   25   United States          North America
# 11     1970      1   25   United States          North America
# 12     1970      1   26   United States          North America
# 13     1970      1   26   United States          North America
# ...

# %%
array = [1972, 1976, 1980, 1984, 1988, 1992, 1994, 1996, 1998, 2000, 2002, 2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018]
OlympicsHostYear = OlympicsHost.loc[(OlympicsHost['Year'].isin(array))]
OlympicsHostYear
# Out:
#        Year  Month  Day         Country                 Region  \
# 333    1972      1    5   United States          North America
# 334    1972      1    7   United States          North America
# 335    1972      1    7   United States          North America
# 336    1972      1    7   United States          North America
# 337    1972      1    7   United States          North America
# 338    1972      1    7   United States          North America
# 339    1972      1    7   United States          North America
# 340    1972      1    7   United States          North America
# 341    1972      1    7   United States          North America
# 342    1972      1   17   United States          North America
# 343    1972      1   17   United States          North America
# 344    1972      2    1   United States          North America
# 345    1972      2    1   United States          North America
# 346    1972      3   11   United States          North America
# ...

# %%
ImptOlympicsHostYear = OlympicsHostYear.drop(['latitude','longitude'], axis =1)
ImptOlympicsHostYear
# Out:
#        Year  Month  Day         Country                 Region  \
# 333    1972      1    5   United States          North America
# 334    1972      1    7   United States          North America
# 335    1972      1    7   United States          North America
# 336    1972      1    7   United States          North America
# 337    1972      1    7   United States          North America
# 338    1972      1    7   United States          North America
# 339    1972      1    7   United States          North America
# 340    1972      1    7   United States          North America
# 341    1972      1    7   United States          North America
# 342    1972      1   17   United States          North America
# 343    1972      1   17   United States          North America
# 344    1972      2    1   United States          North America
# 345    1972      2    1   United States          North America
# 346    1972      3   11   United States          North America
# ...

# %%
m1 = [2,8,9]
m2 = [2,7,8]
m3 = [2,9,10]
m4 = [2]
m5 = [7,8]
m6 = [9,10]
m7 = [8]
m8 = [2,8]
m9 = [2,10]
AttackByOlympicsDates = ImptOlympicsHostYear[(ImptOlympicsHostYear['Year'] == 1972) & (ImptOlympicsHostYear['Month'].isin(m1)) | (ImptOlympicsHostYear['Year'] == 1976) & (ImptOlympicsHostYear['Month'].isin(m2)) | (ImptOlympicsHostYear['Year'] == 1980) & (ImptOlympicsHostYear['Month'].isin(m2)) | (ImptOlympicsHostYear['Year'] == 1984) & (ImptOlympicsHostYear['Month'].isin(m2)) | (ImptOlympicsHostYear['Year'] == 1988) & (ImptOlympicsHostYear['Month'].isin(m3)) | (ImptOlympicsHostYear['Year'] == 1992) & (ImptOlympicsHostYear['Month'].isin(m2)) | (ImptOlympicsHostYear['Year'] == 1994) & (ImptOlympicsHostYear['Month'].isin(m4)) | (ImptOlympicsHostYear['Year'] == 1996) & (ImptOlympicsHostYear['Month'].isin(m5)) | (ImptOlympicsHostYear['Year'] == 1998) & (ImptOlympicsHostYear['Month'].isin(m4)) | (ImptOlympicsHostYear['Year'] == 2000) & (ImptOlympicsHostYear['Month'].isin(m6)) | (ImptOlympicsHostYear['Year'] == 2002) & (ImptOlympicsHostYear['Month'].isin(m4)) | (ImptOlympicsHostYear['Year'] == 2004) & (ImptOlympicsHostYear['Month'].isin(m7)) | (ImptOlympicsHostYear['Year'] == 2006) & (ImptOlympicsHostYear['Month'].isin(m4)) | (ImptOlympicsHostYear['Year'] == 2008) & (ImptOlympicsHostYear['Month'].isin(m7)) | (ImptOlympicsHostYear['Year'] == 2010) & (ImptOlympicsHostYear['Month'].isin(m8)) | (ImptOlympicsHostYear['Year'] == 2012) & (ImptOlympicsHostYear['Month'].isin(m2)) | (ImptOlympicsHostYear['Year'] == 2014) & (ImptOlympicsHostYear['Month'].isin(m8)) | (ImptOlympicsHostYear['Year'] == 2016) & (ImptOlympicsHostYear['Month'].isin(m8)) | (ImptOlympicsHostYear['Year'] == 2018) & (ImptOlympicsHostYear['Month'].isin(m9))]
AttackByOlympicsDates
# Out:
#        Year  Month  Day         Country          Region              city  \
# 344    1972      2    1   United States   North America         Palo Alto
# 345    1972      2    1   United States   North America          El Monte
# 357    1972      8   17   United States   North America     New York City
# 358    1972      8   17   United States   North America     New York City
# 359    1972      8   18   United States   North America     New York City
# 360    1972      8   18   United States   North America     New York City
# 361    1972      8   18   United States   North America     New York City
# 362    1972      9   14   United States   North America       Los Angeles
# 363    1972      9   29   United States   North America     New York City
# 464    1976      2    1   United States   North America     San Francisco
# 476    1976      7    1   United States   North America       Newburyport
# 477    1976      7    4   United States   North America            Revere
# ...

# %%
c1 = ['Japan', 'Germany']
c2 = ['Austria', 'Canada']
c3 = ['United States']
c4 = ['Yugoslavia', 'United States']
c5 = ['Canada', 'South Korea']
c6 = ['France', 'Spain']
c7 = ['Norway']
c8 = ['Japan']
c9 = ['Australia']
c10 = ['Greece']
c11 = ['Italy']
c12 = ['China']
c13 = ['Canada', 'Singapore']
c14 = ['Austria', 'United Kingdom']
c15 = ['Russia', 'China']
c16 = ['Norway','Brazil']
c17 = ['South Korea', 'Argentina']
AttackByOlympicsDatesCountry = AttackByOlympicsDates[(AttackByOlympicsDates['Year'] == 1972) & (AttackByOlympicsDates['Country'].isin(c1)) | (AttackByOlympicsDates['Year'] == 1976) & (AttackByOlympicsDates['Country'].isin(c2)) | (AttackByOlympicsDates['Year'] == 1980) & (AttackByOlympicsDates['Country'].isin(c3)) | (AttackByOlympicsDates['Year'] == 1984) & (AttackByOlympicsDates['Country'].isin(c4)) | (AttackByOlympicsDates['Year'] == 1988) & (AttackByOlympicsDates['Country'].isin(c5)) | (AttackByOlympicsDates['Year'] == 1992) & (AttackByOlympicsDates['Country'].isin(c6)) | (AttackByOlympicsDates['Year'] == 1994) & (AttackByOlympicsDates['Country'].isin(c7)) | (AttackByOlympicsDates['Year'] == 1996) & (AttackByOlympicsDates['Country'].isin(c3)) | (AttackByOlympicsDates['Year'] == 1998) & (AttackByOlympicsDates['Country'].isin(c8)) | (AttackByOlympicsDates['Year'] == 2000) & (AttackByOlympicsDates['Country'].isin(c9)) | (AttackByOlympicsDates['Year'] == 2002) & (AttackByOlympicsDates['Country'].isin(c3)) | (AttackByOlympicsDates['Year'] == 2004) & (AttackByOlympicsDates['Country'].isin(c10)) | (AttackByOlympicsDates['Year'] == 2006) & (AttackByOlympicsDates['Country'].isin(c11)) | (AttackByOlympicsDates['Year'] == 2008) & (AttackByOlympicsDates['Country'].isin(c12)) | (AttackByOlympicsDates['Year'] == 2010) & (AttackByOlympicsDates['Country'].isin(c13)) | (AttackByOlympicsDates['Year'] == 2012) & (AttackByOlympicsDates['Country'].isin(c14)) | (AttackByOlympicsDates['Year'] == 2014) & (AttackByOlympicsDates['Country'].isin(c15)) | (AttackByOlympicsDates['Year'] == 2016) & (AttackByOlympicsDates['Country'].isin(c16)) | (AttackByOlympicsDates['Year'] == 2018) & (AttackByOlympicsDates['Country'].isin(c17))] 
AttackByOlympicsDatesCountry
# Out:
#        Year  Month  Day         Country                 Region  \
# 565    1980      2   20   United States          North America
# 566    1980      2   21   United States          North America
# 578    1980      8    4   United States          North America
# 579    1980      8   20   United States          North America
# 657    1984      2   17   United States          North America
# 658    1984      2   28   United States          North America
# 673    1984      7    4   United States          North America
# 674    1984      7    4   United States          North America
# 675    1984      7    7   United States          North America
# 676    1984      7   19   United States          North America
# 677    1984      8    1   United States          North America
# 678    1984      8   20   United States          North America
# 987    1996      7   11   United States          North America
# 988    1996      8   16   United States          North America
# ...
